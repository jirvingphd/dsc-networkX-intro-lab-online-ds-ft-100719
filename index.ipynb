# %% [markdown]
# # NetworkX Introduction - Lab
#
# ## Introduction
#
# In this lab, you'll practice some of the introductory skills for creating graphs using the NetworkX library introduced in the previous lesson. To do this, you'll create a graph to visualize users and businesses from yelp reviews.
#
# ## Objectives
#
# In this lab you will:
#
# - Create basic network graphs with networkx
# - Add nodes and edges to networkx graphs
# - Visualize network graphs with networkx
#
# ## Import the Data
#
# To start, import the data stored in the file `'Yelp_reviews.csv'`.

# %%
# Your code here
from fsds_100719.imports import *
# Out:
# fsds_1007219  v0.7.4 loaded.  Read the docs: https://fsds.readthedocs.io/en/latest/
# <style  type="text/css" >
# </style><table id="T_c3db0358_4300_11ea_b00f_4865ee12e626" ><caption>Loaded Packages and Handles</caption><thead>    <tr>        <th class="col_heading level0 col0" >Handle</th>        <th class="col_heading level0 col1" >Package</th>        <th class="col_heading level0 col2" >Description</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_c3db0358_4300_11ea_b00f_4865ee12e626row0_col0" class="data row0 col0" >dp</td>
#                         <td id="T_c3db0358_4300_11ea_b00f_4865ee12e626row0_col1" class="data row0 col1" >IPython.display</td>
#                         <td id="T_c3db0358_4300_11ea_b00f_4865ee12e626row0_col2" class="data row0 col2" >Display modules with helpful display and clearing commands.</td>
#             </tr>
#             <tr>
# ...

# %%
df = pd.read_csv('Yelp_reviews.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Data columns (total 10 columns):
# business_id    76 non-null object
# date           76 non-null object
# review_id      76 non-null object
# stars          76 non-null int64
# text           76 non-null object
# type           76 non-null object
# user_id        76 non-null object
# cool           76 non-null int64
# useful         76 non-null int64
# funny          76 non-null int64
# dtypes: int64(4), object(6)
# memory usage: 6.1+ KB

# %% [markdown]
# ## Creating a Graph
#
# Now, create an initial graph!

# %%
# Your code here
import networkx as nx 
G = nx.Graph()

# %% [markdown]
# ## Adding Nodes
#
# Create a node for each user and each business in the dataset. Networks with multiple node types like this are called **bimodal networks**.
#
# Optionally, go further by creating a list of colors for when you visualize the graph. If you do this, append the color "green" to your color list every time you add a user node and append the color "blue" to your color list every time you add a business node.

# %%
# df['user_id']

# %%
# Your code here
colors = []
names = {}
for i,user in enumerate(df['user_id'].unique()):
        names[user] =f"User{i}"
        G.add_node(names[user])
        
        colors.append('green')

for i,business in enumerate(df['business_id'].unique()):
        names[business] = f"Business{i}"
        G.add_node(names[business])
        colors.append('blue')

# %% [markdown]
# ## Adding Edges
#
# Next, iterate through the dataset and create an edge between users and the businesses they have reviewed.

# %%
# Your code here
def apply_edges(row):
    user  =names[row['user_id']]
    business = names[row['business_id']]
    G.add_edge(user,business)

# %%
df.apply(apply_edges,axis=1)
# Out:
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
#       ...
# 71    None
# 72    None
# 73    None
# 74    None
# 75    None
# Length: 76, dtype: object

# %% [markdown]
# ## Visualizing the Graph
#
# Finally, create a visualization of your network. If you chose to color your nodes, pass the list of colors through the optional `node_color` parameter.

# %%
# Your code here
fig,ax= plt.subplots(figsize=(12,12))
nx.draw(G,with_labels=True, alpha=0.7,ax=ax, node_color=colors)
# Out:
# //anaconda3/envs/learn-env/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
#
#
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.

# %% [markdown]
# ## Summary
#
# Nice work! In this lab you created an initial network to visualize a bimodal network of businesses and yelp reviewers!
